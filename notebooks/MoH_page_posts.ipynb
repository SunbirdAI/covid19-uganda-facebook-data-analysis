# %%
import pandas as pd
import seaborn as sns

# %%
posts = pd.read_csv('../data/2020-08-31-MoH-posts.csv')

# %%
posts.head()
# Out:
#                     Page Name      User Name      Facebook Id  \
# 0  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 1  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 2  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 3  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 4  Ministry of Health- Uganda  minofhealthUG  767949523254855
#
#    Likes at Posting                  Created          Type  Likes  Comments  \
# 0            171496  2020-08-05 15:13:59 EAT  Native Video  22209      2690
# 1            181221  2020-08-27 13:22:55 EAT         Photo  23845       287
# 2            180459  2020-08-26 15:56:40 EAT         Photo  14956       171
# 3            173330  2020-08-09 07:00:01 EAT         Photo  13305       708
# 4            175516  2020-08-15 15:05:22 EAT  Native Video  12170       428
#
#    Shares  Love  ...                                            Message  \
# ...

# %% [markdown]
# ## Interaction and sentiment stats for posts

# %% [markdown]
# ### Total interactions

# %%
posts['Total Interactions'] = posts['Total Interactions'].str.replace(',', '').astype(float)

# %%
posts.sort_values(by='Created', ascending=False, inplace=True)
posts.head()
# Out:
#                      Page Name      User Name      Facebook Id  \
# 42  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 41  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 16  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 13  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 10  Ministry of Health- Uganda  minofhealthUG  767949523254855
#
#     Likes at Posting                  Created    Type  Likes  Comments  \
# 42            183323  2020-08-30 17:38:11 EAT  Status    778       526
# 41            183102  2020-08-29 15:24:04 EAT  Status    921       386
# 16            182330  2020-08-28 13:47:33 EAT   Photo   7348       304
# 13            182330  2020-08-28 13:44:12 EAT   Photo   7866       582
# 10            181221  2020-08-27 15:47:46 EAT   Photo   7843      1029
#
#     Shares  Love  ...                                            Message  \
# 42      95     2  ...  Results from COVID-19 tests done on 29 August ...
# ...

# %%
posts.plot.area(x='Created', y=['Total Interactions'], color='Blue', alpha=0.4, figsize=(20,10))

# %% [markdown]
# ### Likes

# %%
posts[['Message', 'Created', 'Likes']].sort_values(by='Likes', ascending=False).head()
# Out:
#                                              Message                  Created  \
# 1  The Minister of Health, Dr. Jane Ruth Aceng Oc...  2020-08-27 13:22:55 EAT
# 0  The President of Uganda, His Excellency, Yower...  2020-08-05 15:13:59 EAT
# 2  Continuous sensitization of leaders and commun...  2020-08-26 15:56:40 EAT
# 3  Door-to-door distribution of face masks has ki...  2020-08-09 07:00:01 EAT
# 4  Dr Phionah Atuhebwe, a Ugandan working at Worl...  2020-08-15 15:05:22 EAT
#
#    Likes
# 1  23845
# 0  22209
# 2  14956
# 3  13305
# 4  12170

# %%
posts.plot.area(x='Created', y='Likes', color='Green', alpha=0.4,  figsize=(20,10))

# %% [markdown]
# ### Angry reactions

# %%
posts[['Message', 'Created', 'Angry']].sort_values(by='Angry', ascending=False).head()
# Out:
#                                               Message  \
# 0   The President of Uganda, His Excellency, Yower...
# 31  Today, Uganda has registered the highest numbe...
# 5   The Ministry of Health confirms one COVID-19 d...
# 10  Results from COVID-19 tests done on 26 August ...
# 7   Uganda has registered one COVID-19 death today...
#
#                     Created  Angry
# 0   2020-08-05 15:13:59 EAT     97
# 31  2020-08-22 19:20:35 EAT     23
# 5   2020-08-01 15:23:16 EAT     21
# 10  2020-08-27 15:47:46 EAT     19
# 7   2020-07-31 19:02:34 EAT     17

# %%
posts.plot.area(x='Created', y='Angry', color='Red', alpha=0.4,  figsize=(20,10))

# %% [markdown]
# ## Annotation and categorization posts

# %% [markdown]
# ### Prepare posts for annotation

# %%
posts_for_annotation = posts[['Facebook Id', 'Message']]
posts_for_annotation.rename(columns={"Message": "text"}, inplace=True)
posts_for_annotation['label'] = ''

# %%
posts_for_annotation.to_csv('MoH-posts-for-annotation.csv')

# %% [markdown]
# ### Analyze annotated posts

# %%
annotated_posts = pd.read_csv('../data/annotated_MoH_posts.csv')
annotated_posts.head()
# Out:
#    annotation_approver   id  label  meta  meta.Facebook Id  \
# 0                  NaN  936      5     9   767949523254855
# 1                  NaN  927      5     0   767949523254855
# 2                  NaN  928      5     1   767949523254855
# 3                  NaN  929      5     2   767949523254855
# 4                  NaN  930      4     3   767949523254855
#
#                                                 text  user
# 0  COVID-19 has impacted our lives in various way...     2
# 1  The President of Uganda, His Excellency, Yower...     2
# 2  The Minister of Health, Dr. Jane Ruth Aceng Oc...     2
# 3  Continuous sensitization of leaders and commun...     2
# 4  Door-to-door distribution of face masks has ki...     2

# %%
post_types = {3:'New cases or deaths', 4:'Masks implementation', 
              5:'Other information (covid)', 6:'Other information (non-covid)'}
annotated_posts['label'] = annotated_posts.label.map(post_types)
annotated_posts.head()
# Out:
#    annotation_approver   id                      label  meta  \
# 0                  NaN  936  Other information (covid)     9
# 1                  NaN  927  Other information (covid)     0
# 2                  NaN  928  Other information (covid)     1
# 3                  NaN  929  Other information (covid)     2
# 4                  NaN  930       Masks implementation     3
#
#    meta.Facebook Id                                               text  user
# 0   767949523254855  COVID-19 has impacted our lives in various way...     2
# 1   767949523254855  The President of Uganda, His Excellency, Yower...     2
# 2   767949523254855  The Minister of Health, Dr. Jane Ruth Aceng Oc...     2
# 3   767949523254855  Continuous sensitization of leaders and commun...     2
# 4   767949523254855  Door-to-door distribution of face masks has ki...     2

# %%
sns.countplot(y='label', data=annotated_posts)
