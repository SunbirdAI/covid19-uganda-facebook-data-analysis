# %%
import pandas as pd

# %%
posts = pd.read_csv('../data/2020-09-30-16-27-26-EAT-Historical-Report-Covid-Funds-search-term-covid-fund-2020-03-30--2020-09-30.csv')

# %%
posts.head(10)
# Out:
#         Page Name     User Name      Facebook Id  Likes at Posting  \
# 0   Daily Monitor  DailyMonitor     105583497196         1271118.0
# 1  The New Vision  thenewvision     329423169077         1358402.0
# 2      NTV Uganda     NTVUganda  169252986456497         1398641.0
# 3          UBC TV     UBCUganda  145508035642581           74494.0
# 4  The New Vision  thenewvision     329423169077         1358402.0
# 5   Daily Monitor  DailyMonitor     105583497196         1271118.0
# 6        93.3 KFM        933KFM     125352480137          379652.0
# 7          UBC TV     UBCUganda  145508035642581           74494.0
# 8   Daily Monitor  DailyMonitor     105583497196         1271118.0
# 9      NTV Uganda     NTVUganda  169252986456497         1398641.0
#
#                    Created                 Type  Likes  Comments  Shares  \
# 0  2020-09-30 15:29:48 EAT                 Link     24         1       0
# 1  2020-09-30 15:21:34 EAT                Photo     64         3       2
# ...

# %%
posts.shape
# Out:
# (9949, 30)
