# %%
import pandas as pd
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
posts = pd.read_csv('../data/2020-11-23-MoH-posts.csv')

# %%
posts.head()
# Out:
#                     Page Name      User Name      Facebook Id  \
# 0  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 1  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 2  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 3  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 4  Ministry of Health- Uganda  minofhealthUG  767949523254855
#
#    Likes at Posting                  Created   Type  Likes  Comments  Shares  \
# 0            198402  2020-11-23 15:22:21 EAT  Photo     63         1       5
# 1            198402  2020-11-23 15:17:46 EAT  Photo     40        12       4
# 2            198148  2020-11-22 20:17:08 EAT  Photo   2092       129      65
# 3            198148  2020-11-22 17:24:34 EAT  Photo   5389       325     311
# 4            198007  2020-11-21 20:02:54 EAT  Photo   2507       232      71
#
#    Love  ...                                                URL  \
# 0     0  ...  https://www.facebook.com/minofhealthUG/posts/3...
# 1     2  ...  https://www.facebook.com/minofhealthUG/posts/3...
# 2     1  ...  https://www.facebook.com/minofhealthUG/posts/3...
# 3    19  ...  https://www.facebook.com/minofhealthUG/posts/3...
# 4     3  ...  https://www.facebook.com/minofhealthUG/posts/3...
#
#                                              Message  \
# 0  Public and Private COVID-19 sample collection ...
# 1  NOTICE: All individuals intending to travel ou...
# 2  Results of COVID-19 tests done on 21 November ...
# 3  NEW: Accredited Laboratories to carry out COVI...
# 4  Results of COVID-19 tests done on 20 November ...
#
#                                                 Link  \
# 0  https://www.facebook.com/minofhealthUG/photos/...
# 1  https://www.facebook.com/minofhealthUG/photos/...
# 2  https://www.facebook.com/minofhealthUG/photos/...
# 3  https://www.facebook.com/minofhealthUG/photos/...
# 4  https://www.facebook.com/minofhealthUG/photos/...
#
#                                           Final Link  \
# 0  https://www.facebook.com/login/?next=https%3A%...
# 1  https://www.facebook.com/login/?next=https%3A%...
# 2  https://www.facebook.com/login/?next=https%3A%...
# 3  https://www.facebook.com/login/?next=https%3A%...
# 4  https://www.facebook.com/login/?next=https%3A%...
#
#                                           Image Text  \
# 0                                                NaN
# 1                                                NaN
# 2  JBI co MINISTRY OF HEALTH COVID-19 DAILY UPDAT...
# 3  The Republic Uganda MINISTRY OF HEALTH NEW Acc...
# 4  MINISTRY OF HEALTH COVID-19 DAILY UPDATES NEW ...
#
#                                        Link Text  Description  Sponsor Id  \
# 0  Photos from Ministry of Health- Uganda's post          NaN         NaN
# 1                                            NaN          NaN         NaN
# 2                                            NaN          NaN         NaN
# 3                                            NaN          NaN         NaN
# 4                                            NaN          NaN         NaN
#
#    Sponsor Name Overperforming Score
# 0           NaN                 1.06
# 1           NaN                -2.62
# 2           NaN                 1.34
# 3           NaN                 3.05
# 4           NaN                 1.26
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Interaction and sentiment stats for posts

# %%
posts.sort_values(by='Created', ascending=False, inplace=True)
posts.head()
# Out:
#                     Page Name      User Name      Facebook Id  \
# 0  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 1  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 2  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 3  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 4  Ministry of Health- Uganda  minofhealthUG  767949523254855
#
#    Likes at Posting                  Created   Type  Likes  Comments  Shares  \
# 0            198402  2020-11-23 15:22:21 EAT  Photo     63         1       5
# 1            198402  2020-11-23 15:17:46 EAT  Photo     40        12       4
# 2            198148  2020-11-22 20:17:08 EAT  Photo   2092       129      65
# 3            198148  2020-11-22 17:24:34 EAT  Photo   5389       325     311
# 4            198007  2020-11-21 20:02:54 EAT  Photo   2507       232      71
#
#    Love  ...                                                URL  \
# 0     0  ...  https://www.facebook.com/minofhealthUG/posts/3...
# 1     2  ...  https://www.facebook.com/minofhealthUG/posts/3...
# 2     1  ...  https://www.facebook.com/minofhealthUG/posts/3...
# 3    19  ...  https://www.facebook.com/minofhealthUG/posts/3...
# 4     3  ...  https://www.facebook.com/minofhealthUG/posts/3...
#
#                                              Message  \
# 0  Public and Private COVID-19 sample collection ...
# 1  NOTICE: All individuals intending to travel ou...
# 2  Results of COVID-19 tests done on 21 November ...
# 3  NEW: Accredited Laboratories to carry out COVI...
# 4  Results of COVID-19 tests done on 20 November ...
#
#                                                 Link  \
# 0  https://www.facebook.com/minofhealthUG/photos/...
# 1  https://www.facebook.com/minofhealthUG/photos/...
# 2  https://www.facebook.com/minofhealthUG/photos/...
# 3  https://www.facebook.com/minofhealthUG/photos/...
# 4  https://www.facebook.com/minofhealthUG/photos/...
#
#                                           Final Link  \
# 0  https://www.facebook.com/login/?next=https%3A%...
# 1  https://www.facebook.com/login/?next=https%3A%...
# 2  https://www.facebook.com/login/?next=https%3A%...
# 3  https://www.facebook.com/login/?next=https%3A%...
# 4  https://www.facebook.com/login/?next=https%3A%...
#
#                                           Image Text  \
# 0                                                NaN
# 1                                                NaN
# 2  JBI co MINISTRY OF HEALTH COVID-19 DAILY UPDAT...
# 3  The Republic Uganda MINISTRY OF HEALTH NEW Acc...
# 4  MINISTRY OF HEALTH COVID-19 DAILY UPDATES NEW ...
#
#                                        Link Text  Description  Sponsor Id  \
# 0  Photos from Ministry of Health- Uganda's post          NaN         NaN
# 1                                            NaN          NaN         NaN
# 2                                            NaN          NaN         NaN
# 3                                            NaN          NaN         NaN
# 4                                            NaN          NaN         NaN
#
#    Sponsor Name Overperforming Score
# 0           NaN                 1.06
# 1           NaN                -2.62
# 2           NaN                 1.34
# 3           NaN                 3.05
# 4           NaN                 1.26
#
# [5 rows x 30 columns]

# %%
posts.groupby(by='Type').count()
# Out:
#                      Page Name  User Name  Facebook Id  Likes at Posting  \
# Type
# Live Video Complete          1          1            1                 1
# Native Video                 1          1            1                 1
# Photo                       41         41           41                41
#
#                      Created  Likes  Comments  Shares  Love  Wow  ...  URL  \
# Type                                                              ...
# Live Video Complete        1      1         1       1     1    1  ...    1
# Native Video               1      1         1       1     1    1  ...    1
# Photo                     41     41        41      41    41   41  ...   41
#
#                      Message  Link  Final Link  Image Text  Link Text  \
# Type
# Live Video Complete        0     1           1           0          0
# Native Video               1     1           1           0          1
# Photo                     41    41          25          31         11
#
#                      Description  Sponsor Id  Sponsor Name  \
# Type
# Live Video Complete            0           0             0
# Native Video                   0           0             0
# Photo                          0           0             0
#
#                      Overperforming Score
# Type
# Live Video Complete                     1
# Native Video                            1
# Photo                                  41
#
# [3 rows x 29 columns]

# %% [markdown]
# ### Likes

# %%
posts[['Message', 'Created', 'Likes']].sort_values(by='Likes', ascending=False).head()
# Out:
#                                               Message  \
# 36  The training of COVID-19 Retrieval Teams by Mi...
# 42  Results of COVID-19 tests done on 29 October 2...
# 23  Results of COVID-19 tests done on 10 November ...
# 41  Results of COVID-19 tests done on 30 October 2...
# 3   NEW: Accredited Laboratories to carry out COVI...
#
#                     Created  Likes
# 36  2020-11-04 13:45:39 EAT   8883
# 42  2020-10-30 20:19:20 EAT   5669
# 23  2020-11-11 18:46:27 EAT   5589
# 41  2020-10-31 18:57:19 EAT   5572
# 3   2020-11-22 17:24:34 EAT   5389

# %% [markdown]
# ### Angry reactions

# %%
posts[['Message', 'Created', 'Angry']].sort_values(by='Angry', ascending=False).head(5)
# Out:
#                                               Message  \
# 42  Results of COVID-19 tests done on 29 October 2...
# 34  Results from COVID-19 tests done on 4 November...
# 41  Results of COVID-19 tests done on 30 October 2...
# 23  Results of COVID-19 tests done on 10 November ...
# 17  Results of COVID-19 tests done on 13 November ...
#
#                     Created  Angry
# 42  2020-10-30 20:19:20 EAT      5
# 34  2020-11-05 17:42:26 EAT      5
# 41  2020-10-31 18:57:19 EAT      4
# 23  2020-11-11 18:46:27 EAT      4
# 17  2020-11-14 17:23:47 EAT      4

# %%
posts.plot.area(x='Created', y='Angry', color='Red', alpha=0.4,  figsize=(20,10))

# %% [markdown]
# ## Annotation

# %% [markdown]
# ### Prepare posts for annotation

# %%
posts_for_annotation = posts[['Facebook Id','Message']]
posts_for_annotation.rename(columns={"Message": "text"}, inplace=True)
posts_for_annotation['label'] = ''

# %%
posts_for_annotation.to_csv('MoH-posts-for-annotation-6.csv')

# %% [markdown]
# ### Analyze annotated posts

# %%
annotated_posts = pd.read_csv('../data/annotated_MoH_posts_.csv', index_col=[0])
annotated_posts.head(10)
# Out:
#        Facebook Id                                               text  \
# 0  767949523254855  Public and Private COVID-19 sample collection ...
# 1  767949523254855  NOTICE: All individuals intending to travel ou...
# 2  767949523254855  Results of COVID-19 tests done on 21 November ...
# 3  767949523254855  NEW: Accredited Laboratories to carry out COVI...
# 4  767949523254855  Results of COVID-19 tests done on 20 November ...
# 5  767949523254855  Results of COVID-19 tests done on 19 November ...
# 6  767949523254855  Results of COVID-19 tests done on 18 November ...
# 7  767949523254855  Results of COVID-19 tests done on 17 November ...
# 8  767949523254855  The Ministry of Health team led by the Permane...
# 9  767949523254855  The Permanent Secretary, Dr. Diana Atwine rece...
#
#                        label
# 0    Other COVID information
# 1    Other COVID information
# 2  New COVID cases or deaths
# 3    Other COVID information
# 4  New COVID cases or deaths
# 5  New COVID cases or deaths
# 6  New COVID cases or deaths
# 7  New COVID cases or deaths
# 8      Non-COVID information
# 9      Non-COVID information

# %%
annotated_posts['category'] = annotated_posts['label'].astype('category')
annotated_posts['category']
# Out:
# 0       Other COVID information
# 1       Other COVID information
# 2     New COVID cases or deaths
# 3       Other COVID information
# 4     New COVID cases or deaths
# 5     New COVID cases or deaths
# 6     New COVID cases or deaths
# 7     New COVID cases or deaths
# 8         Non-COVID information
# 9         Non-COVID information
# 10      Other COVID information
# 11        Non-COVID information
# 12    New COVID cases or deaths
# 13        Non-COVID information
# 14        Non-COVID information
# 15    New COVID cases or deaths
# 16    New COVID cases or deaths
# 17    New COVID cases or deaths
# 18      Other COVID information
# 19    New COVID cases or deaths
# 20    New COVID cases or deaths
# 21        Non-COVID information
# 22      Other COVID information
# 23    New COVID cases or deaths
# 24        Non-COVID information
# 25    New COVID cases or deaths
# 26    New COVID cases or deaths
# 27    New COVID cases or deaths
# 28        Non-COVID information
# 29    New COVID cases or deaths
# 30        Non-COVID information
# 31    New COVID cases or deaths
# 32        Non-COVID information
# 33        Non-COVID information
# 34    New COVID cases or deaths
# 35    New COVID cases or deaths
# 36      Other COVID information
# 37    New COVID cases or deaths
# 38        Non-COVID information
# 39    New COVID cases or deaths
# 40    New COVID cases or deaths
# 41    New COVID cases or deaths
# 42    New COVID cases or deaths
# Name: category, dtype: category
# Categories (3, object): [New COVID cases or deaths, Non-COVID information, Other COVID information]

# %%
sns.countplot(y='category', data=annotated_posts)

# %%
final_df = annotated_posts[['text', 'category']]
final_df.head(5)
# Out:
#                                                 text  \
# 0                                                NaN
# 1  Results from COVID-19 tests done on 12 Novembe...
# 2  Results of COVID-19 tests done on 11 November ...
# 3  On behalf of the Ministry of Health, The Perma...
# 4  WEBINAR: Unmasking the Peculiar Clinical, Radi...
#
#                     category
# 0    Other COVID information
# 1  New COVID cases or deaths
# 2  New COVID cases or deaths
# 3      Non-COVID information
# 4    Other COVID information

# %%
final_df.to_csv('MoH-posts-text-5.csv')
