# %%
import pandas as pd

# %%
posts = pd.read_csv('2020-08-19-12-13-18-EAT-Historical-Report-1970-01-01--2020-08-19.csv')
# Out:
# /home/lydia/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
posts = posts[['Facebook Id', 'Message', 'Description']]
posts.dropna(subset=['Message', 'Description'], inplace=True)
posts['text'] = posts['Message'].str.cat(posts['Description'], sep=' \n ', na_rep='')
posts['label'] = ''
posts
# Out:
# /home/lydia/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lydia/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#             Facebook Id  \
# 1       169252986456497
# 23         105583497196
# 27         105583497196
# 28      169252986456497
# 45      169252986456497
# ...                 ...
# 299938     274577061337
# 299943  169252986456497
# 299947     274577061337
# 299951  169252986456497
# 299955  169252986456497
#
#                                                                                                               Message  \
# 1       NTV BIZ: With bad loans at more than 50% for the Equity Bank group and subsequently requiring higher provi...
# 23      Police summon Tumukunde over meetings with army veterans https://bit.ly/3l16M7h:=:https://www.monitor.co.u...
# 27      The battle for top positions in the Central Executive Committee (CEC) of the NRM party is shaping up as ca...
# 28      The Uganda Law Society has written to the Law Council to take disciplinary action against the advocates ta...
# 45      Presidential Aspirant and former Security minister Lt. General Henry Tumukunde was on Tuesday arrested for...
# ...                                                                                                               ...
# 299938                                   Only true leaders know when to be political and when to be responsible. #ANT
# 299943  About 3.4 million Uganda will be pushed into poverty as a result of the #Coronavirus pandemic on Uganda’s ...
# 299947  "What kind of quarantine is this where there is no care whether we infect each other at all! There isn’t e...
# 299951                              #Mwasuzemutya Emboozi ya Dj Jacob Omutuuze www.ntv.co.ug:=:https://www.ntv.co.ug/
# 299955  All court hearings and appearances have been suspended for 32 days with effect from Friday 20th March 2020...
#
#                                                                                                           Description  \
# 1       With bad loans at more than 50% for the Equity Bank group and subsequently requiring higher provisioning, ...
# 23      The former intelligence chief is currently battling treason and illegal possession of firearms charges tha...
# 27      NEC members are expected to endorse the names of the candidates for the positions of 1st national vice cha...
# 28      The Uganda Law Society has written to the Law Council to take disciplinary action against the advocates ta...
# 45      Presidential Aspirant and former Security minister Lt. General Henry Tumukunde was arrested on Tuesday aft...
# ...                                                                                                               ...
# 299938  As we continue to do all we can as a country to stave off the Coronavirus pandemic, The Alliance For Natio...
# 299943  About 3.4 million Uganda will be pushed into poverty as a result of the coronavirus pandemic on Uganda’s e...
# 299947  The Uganda Civil Aviation Authority (CAA) is on the spot over selective application of directives on coron...
# 299951                                                                     #Mwasuzemutya Emboozi ya Dj Jacob Omutuuze
# 299955  All court hearings and appearances have been suspended for 32 days with effect from Friday 20th March 2020...
#
#                                                                                                                  text  \
# 1       NTV BIZ: With bad loans at more than 50% for the Equity Bank group and subsequently requiring higher provi...
# 23      Police summon Tumukunde over meetings with army veterans https://bit.ly/3l16M7h:=:https://www.monitor.co.u...
# 27      The battle for top positions in the Central Executive Committee (CEC) of the NRM party is shaping up as ca...
# 28      The Uganda Law Society has written to the Law Council to take disciplinary action against the advocates ta...
# 45      Presidential Aspirant and former Security minister Lt. General Henry Tumukunde was on Tuesday arrested for...
# ...                                                                                                               ...
# 299938  Only true leaders know when to be political and when to be responsible. #ANT \n As we continue to do all w...
# 299943  About 3.4 million Uganda will be pushed into poverty as a result of the #Coronavirus pandemic on Uganda’s ...
# 299947  "What kind of quarantine is this where there is no care whether we infect each other at all! There isn’t e...
# 299951  #Mwasuzemutya Emboozi ya Dj Jacob Omutuuze www.ntv.co.ug:=:https://www.ntv.co.ug/ \n #Mwasuzemutya Emboozi...
# 299955  All court hearings and appearances have been suspended for 32 days with effect from Friday 20th March 2020...
#
#        label
# 1
# 23
# 27
# 28
# 45
# ...      ...
# 299938
# 299943
# 299947
# 299951
# 299955
#
# [32028 rows x 5 columns]

# %%
posts.drop(columns=['Message', 'Description'], inplace=True)

# %%
posts.head()
# Out:
#         Facebook Id  \
# 1   169252986456497
# 23     105583497196
# 27     105583497196
# 28  169252986456497
# 45  169252986456497
#
#                                                                                                              text  \
# 1   NTV BIZ: With bad loans at more than 50% for the Equity Bank group and subsequently requiring higher provi...
# 23  Police summon Tumukunde over meetings with army veterans https://bit.ly/3l16M7h:=:https://www.monitor.co.u...
# 27  The battle for top positions in the Central Executive Committee (CEC) of the NRM party is shaping up as ca...
# 28  The Uganda Law Society has written to the Law Council to take disciplinary action against the advocates ta...
# 45  Presidential Aspirant and former Security minister Lt. General Henry Tumukunde was on Tuesday arrested for...
#
#    label
# 1
# 23
# 27
# 28
# 45

# %%
sample_posts = posts.head(2000)

# %%
sample_posts.to_csv('sample_posts_text.csv')
