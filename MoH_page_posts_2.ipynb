# %%
import pandas as pd
import seaborn as sns

# %%
posts = pd.read_csv('data/2020-09-23-MoH-posts.csv')

# %%
posts.head()
# Out:
#                     Page Name      User Name      Facebook Id  \
# 0  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 1  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 2  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 3  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 4  Ministry of Health- Uganda  minofhealthUG  767949523254855
#
#    Likes at Posting                  Created          Type  Likes  Comments  \
# 0            171496  2020-08-05 15:13:59 EAT  Native Video  22209      2690
# 1            181221  2020-08-27 13:22:55 EAT         Photo  23845       287
# 2            180459  2020-08-26 15:56:40 EAT         Photo  14956       171
# 3            173330  2020-08-09 07:00:01 EAT         Photo  13305       708
# 4            175516  2020-08-15 15:05:22 EAT  Native Video  12170       428
#
#    Shares  Love  ...                                            Message  \
# 0    4273   812  ...  The President of Uganda, His Excellency, Yower...
# 1      66    35  ...  The Minister of Health, Dr. Jane Ruth Aceng Oc...
# 2      30    14  ...  Continuous sensitization of leaders and commun...
# 3     135    39  ...  Door-to-door distribution of face masks has ki...
# 4     744    87  ...  Dr Phionah Atuhebwe, a Ugandan working at Worl...
#
#                                                 Link  Final Link  Image Text  \
# 0  https://www.facebook.com/minofhealthUG/videos/...         NaN         NaN
# 1  https://www.facebook.com/minofhealthUG/photos/...         NaN         NaN
# 2  https://www.facebook.com/minofhealthUG/photos/...         NaN         NaN
# 3  https://www.facebook.com/minofhealthUG/photos/...         NaN         NaN
# 4  https://www.facebook.com/minofhealthUG/videos/...         NaN         NaN
#
#                                        Link Text Description  Sponsor Id  \
# 0                President Museveni Indoor Video         NaN         NaN
# 1  Photos from Ministry of Health- Uganda's post         NaN         NaN
# 2                                            NaN         NaN         NaN
# 3  Photos from Ministry of Health- Uganda's post         NaN         NaN
# 4    Testimony from a Ugandan COVID-19 survivor.         NaN         NaN
#
#    Sponsor Name  Total Interactions  \
# 0           NaN              31,098
# 1           NaN              24,272
# 2           NaN              15,181
# 3           NaN              14,275
# 4           NaN              13,549
#
#   Total Interactions (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )
# 0                                             31,098
# 1                                             24,272
# 2                                             15,181
# 3                                             14,275
# 4                                             13,549
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Interaction and sentiment stats for posts

# %% [markdown]
# ### Total interactions

# %%
posts['Total Interactions'] = posts['Total Interactions'].str.replace(',', '').astype(float)

# %%
posts.sort_values(by='Created', ascending=False, inplace=True)
posts.head()
# Out:
#                      Page Name      User Name      Facebook Id  \
# 0   Ministry of Health- Uganda  minofhealthUG  767949523254855
# 32  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 43  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 11  Ministry of Health- Uganda  minofhealthUG  767949523254855
# 36  Ministry of Health- Uganda  minofhealthUG  767949523254855
#
#     Likes at Posting                  Created          Type  Likes  Comments  \
# 0             187770  2020-09-22 16:09:57 EAT         Photo  11598       173
# 32            187770  2020-09-22 14:57:27 EAT         Photo    656       127
# 43            187541  2020-09-21 22:11:49 EAT  Native Video     68        11
# 11            187541  2020-09-21 13:38:32 EAT         Photo   3337       348
# 36            187541  2020-09-21 10:56:53 EAT         Photo    624        25
#
#     Shares  Love  ...                                            Message  \
# 0       55    19  ...  The COVID-19 response has been boosted with an...
# 32      87     4  ...  Results of COVID-19 tests done on 21 September...
# 43      14     1  ...                                       #YambalaMask
# 11      95     5  ...  Results of COVID-19 tests done on 20 September...
# 36      21     3  ...  The Permanent Secretary, Dr. Diana Atwine and ...
#
#                                                  Link  Final Link  \
# 0   https://www.facebook.com/minofhealthUG/photos/...         NaN
# 32  https://www.facebook.com/minofhealthUG/photos/...         NaN
# 43  https://www.facebook.com/funfactoryuganda/vide...         NaN
# 11  https://www.facebook.com/minofhealthUG/photos/...         NaN
# 36  https://www.facebook.com/minofhealthUG/photos/...         NaN
#
#                                            Image Text  \
# 0                                                 NaN
# 32  THE REPU FUGANDA MINISTRY OF HEALTH COVID-19 D...
# 43                                                NaN
# 11  REPU FUGANDA MINISTRY OF HEALTH COVID-19 DAILY...
# 36                                                NaN
#
#                                         Link Text  \
# 0   Photos from Ministry of Health- Uganda's post
# 32                                            NaN
# 43                             Fun Factory Uganda
# 11                                            NaN
# 36  Photos from Ministry of Health- Uganda's post
#
#                                           Description  Sponsor Id  \
# 0                                                 NaN         NaN
# 32                                                NaN         NaN
# 43  🥁🥁DRUM ROLL💃🕺THE WAITING IS OVER.\n\nLadies an...         NaN
# 11                                                NaN         NaN
# 36                                                NaN         NaN
#
#     Sponsor Name  Total Interactions  \
# 0            NaN             11862.0
# 32           NaN               906.0
# 43           NaN                97.0
# 11           NaN              3829.0
# 36           NaN               674.0
#
#    Total Interactions (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )
# 0                                              11,862
# 32                                                906
# 43                                                 97
# 11                                              3,829
# 36                                                674
#
# [5 rows x 31 columns]

# %%
posts.plot.area(x='Created', y=['Total Interactions'], color='Blue', alpha=0.4, figsize=(20,10))

# %% [markdown]
# ### Likes

# %%
posts[['Message', 'Created', 'Likes']].sort_values(by='Likes', ascending=False).head()
# Out:
#                                              Message                  Created  \
# 0  The COVID-19 response has been boosted with an...  2020-09-22 16:09:57 EAT
# 1  The Minister for Health Dr. Jane Ruth Aceng Oc...  2020-09-16 11:52:05 EAT
# 2  Results from COVID-19 tests done on 19 Septemb...  2020-09-20 15:36:29 EAT
# 3  Do not discriminate against individuals who ha...  2020-09-10 07:58:02 EAT
# 4  Since the onset of the COVID-19 outbreak, 300 ...  2020-09-19 10:00:54 EAT
#
#    Likes
# 0  11598
# 1  11000
# 2   6223
# 3   5111
# 4   5079

# %%
posts.plot.area(x='Created', y='Likes', color='Green', alpha=0.4,  figsize=(20,10))

# %% [markdown]
# ### Angry reactions

# %%
posts[['Message', 'Created', 'Angry']].sort_values(by='Angry', ascending=False).head()
# Out:
#                                               Message  \
# 21  Results from COVID-19 tests done on 11 Septemb...
# 19  Results from COVID-19 tests done on 18 Septemb...
# 8   Results of COVID-19 tests done on 09 September...
# 12  Results of COVID-19 tests done on 17 September...
# 14  Results of COVID-19 tests done on 02 September...
#
#                     Created  Angry
# 21  2020-09-12 17:44:12 EAT     11
# 19  2020-09-19 13:39:57 EAT      8
# 8   2020-09-10 15:10:19 EAT      6
# 12  2020-09-18 13:01:48 EAT      6
# 14  2020-09-03 16:00:02 EAT      6

# %%
posts.plot.area(x='Created', y='Angry', color='Red', alpha=0.4,  figsize=(20,10))

# %% [markdown]
# ## Annotation and categorization posts

# %% [markdown]
# ### Prepare posts for annotation

# %%
posts_for_annotation = posts[['Facebook Id', 'Message']]
posts_for_annotation.rename(columns={"Message": "text"}, inplace=True)
posts_for_annotation['label'] = ''

# %%
posts_for_annotation.to_csv('MoH-posts-for-annotation-2.csv')

# %% [markdown]
# ### Analyze annotated posts

# %%
annotated_posts = pd.read_csv('data/annotated_MoH_posts_2.csv')
annotated_posts.head(10)
# Out:
#    annotation_approver    id  label  meta  meta.Facebook Id  \
# 0                  NaN  8799     24     0   767949523254855
# 1                  NaN  8800     23    32   767949523254855
# 2                  NaN  8801     24    43   767949523254855
# 3                  NaN  8802     23    11   767949523254855
# 4                  NaN  8803     25    36   767949523254855
# 5                  NaN  8804     23     2   767949523254855
# 6                  NaN  8805     23    19   767949523254855
# 7                  NaN  8806     24     4   767949523254855
# 8                  NaN  8807     23    12   767949523254855
# 9                  NaN  8808     25    39   767949523254855
#
#                                                 text  user
# 0  The COVID-19 response has been boosted with an...     2
# 1  Results of COVID-19 tests done on 21 September...     2
# 2                                       #YambalaMask     2
# 3  Results of COVID-19 tests done on 20 September...     2
# 4  The Permanent Secretary, Dr. Diana Atwine and ...     2
# 5  Results from COVID-19 tests done on 19 Septemb...     2
# 6  Results from COVID-19 tests done on 18 Septemb...     2
# 7  Since the onset of the COVID-19 outbreak, 300 ...     2
# 8  Results of COVID-19 tests done on 17 September...     2
# 9  Sleeping under a mosquito net protects you and...     2

# %%
post_types = {23:'New COVID cases or deaths', 24:'Other COVID information', 25:'Non-COVID information'}
annotated_posts['label'] = annotated_posts.label.map(post_types)
annotated_posts.head()
# Out:
#    annotation_approver    id                      label  meta  \
# 0                  NaN  8799    Other COVID information     0
# 1                  NaN  8800  New COVID cases or deaths    32
# 2                  NaN  8801    Other COVID information    43
# 3                  NaN  8802  New COVID cases or deaths    11
# 4                  NaN  8803      Non-COVID information    36
#
#    meta.Facebook Id                                               text  user
# 0   767949523254855  The COVID-19 response has been boosted with an...     2
# 1   767949523254855  Results of COVID-19 tests done on 21 September...     2
# 2   767949523254855                                       #YambalaMask     2
# 3   767949523254855  Results of COVID-19 tests done on 20 September...     2
# 4   767949523254855  The Permanent Secretary, Dr. Diana Atwine and ...     2

# %%
sns.countplot(y='label', data=annotated_posts)
